# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="300" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # Test Environment for Generative AI classroom labs
#
# This lab provides a test environment for the codes generated using the Generative AI classroom.
#
# Follow the instructions below to set up this environment for further use.

# %% [markdown]
# # Setup

# %% [markdown]
# ### Install required libraries
#
# In case of a requirement of installing certain python libraries for use in your task, you may do so as shown below.

# %%
# %pip install seaborn nbformat plotly
# Out:
# Requirement already satisfied: seaborn in /Users/jj/Projects/ibmds/.venv/lib/python3.14/site-packages (0.13.2)
# Requirement already satisfied: nbformat in /Users/jj/Projects/ibmds/.venv/lib/python3.14/site-packages (5.10.4)
# Requirement already satisfied: plotly in /Users/jj/Projects/ibmds/.venv/lib/python3.14/site-packages (5.24.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/jj/Projects/ibmds/.venv/lib/python3.14/site-packages (from seaborn) (2.2.0)
# Requirement already satisfied: pandas>=1.2 in /Users/jj/Projects/ibmds/.venv/lib/python3.14/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/jj/Projects/ibmds/.venv/lib/python3.14/site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/jj/Projects/ibmds/.venv/lib/python3.14/site-packages (from nbformat) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/jj/Projects/ibmds/.venv/lib/python3.14/site-packages (from nbformat) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/jj/Projects/ibmds/.venv/lib/python3.14/site-packages (from nbformat) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in /Users/jj/Projects/ibmds/.venv/lib/python3.14/site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/jj/Projects/ibmds/.venv/lib/python3.14/site-packages (from plotly) (9.1.4)
# Requirement already satisfied: packaging in /Users/jj/Projects/ibmds/.venv/lib/python3.14/site-packages (from plotly) (25.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/jj/Projects/ibmds/.venv/lib/python3.14/site-packages (from jsonschema>=2.6->nbformat) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/jj/Projects/ibmds/.venv/lib/python3.14/site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/jj/Projects/ibmds/.venv/lib/python3.14/site-packages (from jsonschema>=2.6->nbformat) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/jj/Projects/ibmds/.venv/lib/python3.14/site-packages (from jsonschema>=2.6->nbformat) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/jj/Projects/ibmds/.venv/lib/python3.14/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jj/Projects/ibmds/.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/jj/Projects/ibmds/.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jj/Projects/ibmds/.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/jj/Projects/ibmds/.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/jj/Projects/ibmds/.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/jj/Projects/ibmds/.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jj/Projects/ibmds/.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/jj/Projects/ibmds/.venv/lib/python3.14/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/jj/Projects/ibmds/.venv/lib/python3.14/site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in /Users/jj/Projects/ibmds/.venv/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Dataset URL from the GenAI lab
# Use the URL provided in the GenAI lab in the cell below.

# %%
URL = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-Coursera/laptop_pricing_dataset_mod1.csv"

# %% [markdown]
# ### Downloading the dataset
#
# Execute the following code to download the dataset in to the interface.
#
# > Please note that this step is essential in JupyterLite. If you are using a downloaded version of this notebook and running it on JupyterLabs, then you can skip this step and directly use the URL in pandas.read_csv() function to read the dataset as a dataframe

# %%
import urllib.request

def download(url, filename):
    urllib.request.urlretrieve(url, filename)

path = URL

download(path, "dataset.csv")
file_name  = "dataset.csv"

# %% [markdown]
# ---

# %% [markdown]
# # Test Environment

# %%
# Keep appending the code generated to this cell, or add more cells below this to execute in parts
import pandas as pd

# Path to the CSV file
file_path = "/Users/jj/Projects/ibmds/11-generative-AI/dataset.csv"

# Read the CSV into a DataFrame. By default, header=0, so the first row is treated as column names.
df = pd.read_csv(file_path)

# Optional: display basic information about the loaded DataFrame
print(df.head())
print('Rows:', len(df), 'Columns:', len(df.columns))
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
#
#    Screen_Size_cm  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price
# 0          35.560            1.6       8             256       1.60    978
# 1          39.624            2.0       4             256       2.20    634
# 2          39.624            2.7       8             256       2.20    946
# 3          33.782            1.6       8             128       1.22   1244
# 4          39.624            1.8       8             256       1.91    837
# Rows: 238 Columns: 13

# %%
import pandas as pd

# Path to the CSV file
file_path = "/Users/jj/Projects/ibmds/11-generative-AI/dataset.csv"

# Read the CSV into a DataFrame (first row treated as headers by default)
df = pd.read_csv(file_path)

# Identify columns that contain any missing values
cols_with_missing = df.columns[df.isna().any()].tolist()

# Output the list of columns with missing values
print("Columns with missing values:", cols_with_missing)

# Optional: display missing value counts per column
missing_counts = df.isna().sum()
print("Missing values per column:")
print(missing_counts)
# Out:
# Columns with missing values: ['Screen_Size_cm', 'Weight_kg']
# Missing values per column:
# Unnamed: 0        0
# Manufacturer      0
# Category          0
# Screen            0
# GPU               0
# OS                0
# CPU_core          0
# Screen_Size_cm    4
# CPU_frequency     0
# RAM_GB            0
# Storage_GB_SSD    0
# Weight_kg         5
# Price             0
# dtype: int64

# %%
import pandas as pd

# df is the existing DataFrame
# 1) Replace missing values in the categorical column with its most frequent value
screen_size_mode = df['Screen_Size_cm'].mode().iloc[0]

# 2) Replace missing values in the continuous column with its mean value
weight_kg_mean = df['Weight_kg'].mean()

# Apply the replacements using .loc to avoid chained-assignment warnings/errors
df.loc[:, 'Screen_Size_cm'] = df['Screen_Size_cm'].fillna(screen_size_mode)
df.loc[:, 'Weight_kg'] = df['Weight_kg'].fillna(weight_kg_mean)

# %%
df.loc[:, 'Screen_Size_cm'] = df['Screen_Size_cm'].astype(float)
df.loc[:, 'Weight_kg'] = df['Weight_kg'].astype(float)

# %%
# Convert Screen_Size_cm (cm) to Screen_Size_inch and rename the column
# Create a new column with inches and drop the original centimeter column
df.loc[:, 'Screen_Size_inch'] = df['Screen_Size_cm'] / 2.54
df = df.drop(columns=['Screen_Size_cm'])

# Convert Weight_kg (kg) to Weight_pounds and rename the column
# Create a new column with pounds and drop the original kilogram column
df.loc[:, 'Weight_pounds'] = df['Weight_kg'] * 2.2046226218
df = df.drop(columns=['Weight_kg'])

# %%
df.loc[:, 'CPU_frequency'] = df['CPU_frequency'] / df['CPU_frequency'].max()

# %%
# 1) Convert 'Screen' into indicator variables named 'Screen_<value>'
df1 = pd.get_dummies(df['Screen'], prefix='Screen')

# 2) Append the indicator variables to the original DataFrame
df = df.join(df1)

# 3) Drop the original 'Screen' column from the DataFrame
df.drop(columns=['Screen'], inplace=True)

# %%
max_val = df['CPU_frequency'].max() 
df['CPU_frequency'] = df['CPU_frequency'] / max_val

# %% [markdown]
# ## Authors

# %% [markdown]
# [Abhishek Gagneja](https://www.linkedin.com/in/abhishek-gagneja-23051987/)

# %% [markdown]
# ## Change Log

# %% [markdown]
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2023-12-10|0.1|Abhishek Gagneja|Initial Draft created|

# %% [markdown]
# Copyright © 2023 IBM Corporation. All rights reserved.
